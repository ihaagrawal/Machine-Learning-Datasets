# %%
#importing libraries
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#reading the dataset
df=pd.read_csv('iris.data')

# %%
df.tail(100)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width          species
# 50            7.0          3.2           4.7          1.4  Iris-versicolor
# 51            6.4          3.2           4.5          1.5  Iris-versicolor
# 52            6.9          3.1           4.9          1.5  Iris-versicolor
# 53            5.5          2.3           4.0          1.3  Iris-versicolor
# 54            6.5          2.8           4.6          1.5  Iris-versicolor
# ..            ...          ...           ...          ...              ...
# 145           6.7          3.0           5.2          2.3   Iris-virginica
# 146           6.3          2.5           5.0          1.9   Iris-virginica
# 147           6.5          3.0           5.2          2.0   Iris-virginica
# 148           6.2          3.4           5.4          2.3   Iris-virginica
# 149           5.9          3.0           5.1          1.8   Iris-virginica
#
# [100 rows x 5 columns]

# %%
#naming the columns
col = ["sepal_length", "sepal_width", "petal_length", "petal_width", "species"]
df=pd.read_csv('iris.data',names=col)

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
#checking the datatypes and stats

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
df.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
#chcking for null values

# %%
df.isnull().sum()
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64

# %%
#we have no null values in the dataset

# %%
#exploratory analysis

# %%
sns.pairplot(data=df,hue='species')

# %%
#we can clearly see from the pairplot that iris-setosa is different from the other two species

# %%
#scatterplots

# %%
sns.scatterplot(x='sepal_length',y='sepal_width',data=df,hue='species')
# Out:
# <Axes: xlabel='sepal_length', ylabel='sepal_width'>

# %%
sns.scatterplot(x='sepal_length',y='petal_length',data=df,hue='species')
# Out:
# <Axes: xlabel='sepal_length', ylabel='petal_length'>

# %%
sns.scatterplot(x='sepal_length',y='petal_width',data=df,hue='species')
# Out:
# <Axes: xlabel='sepal_length', ylabel='petal_width'>

# %%
sns.scatterplot(x='sepal_width',y='petal_length',data=df,hue='species')
# Out:
# <Axes: xlabel='sepal_width', ylabel='petal_length'>

# %%
sns.scatterplot(x='sepal_width',y='petal_width',data=df,hue='species')
# Out:
# <Axes: xlabel='sepal_width', ylabel='petal_width'>

# %%
sns.scatterplot(x='petal_length',y='petal_width',data=df,hue='species')
# Out:
# <Axes: xlabel='petal_length', ylabel='petal_width'>

# %%
#in all the above scatterplots it's clear that iris setosa has different characteristics than the other two
#the other two species overlap at some places

# %%
#splitting the model

# %%
X=df.drop('species',axis=1)
y=df['species']

# %%
X
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 0             5.1          3.5           1.4          0.2
# 1             4.9          3.0           1.4          0.2
# 2             4.7          3.2           1.3          0.2
# 3             4.6          3.1           1.5          0.2
# 4             5.0          3.6           1.4          0.2
# ..            ...          ...           ...          ...
# 145           6.7          3.0           5.2          2.3
# 146           6.3          2.5           5.0          1.9
# 147           6.5          3.0           5.2          2.0
# 148           6.2          3.4           5.4          2.3
# 149           5.9          3.0           5.1          1.8
#
# [150 rows x 4 columns]

# %%
y
# Out:
# 0         Iris-setosa
# 1         Iris-setosa
# 2         Iris-setosa
# 3         Iris-setosa
# 4         Iris-setosa
#             ...
# 145    Iris-virginica
# 146    Iris-virginica
# 147    Iris-virginica
# 148    Iris-virginica
# 149    Iris-virginica
# Name: species, Length: 150, dtype: object

# %%
#train and test split

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3,random_state=42)

# %%
#training the model

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import AdaBoostClassifier, GradientBoostingClassifier, RandomForestClassifier
from sklearn.svm import SVC
from sklearn.metrics import classification_report,accuracy_score
from sklearn.metrics import confusion_matrix

# %%
#fiiting and predicting

# %%
def model(model,data):
    
    model.fit(X_train,y_train)
    y_pred=model.predict(X_test)
    
    print(classification_report(y_test,y_pred))
    print('\n')
    print(f"The accuracy is {(accuracy_score(y_test,y_pred).round(2))}")
    print('\n')
    
    confusion_matrix(y_test,y_pred)
    cm=confusion_matrix(y_test,y_pred,labels=['Iris-setosa','Iris-versicolor','Iris-virginica'])
    df_cm=pd.DataFrame(cm,index=[i for i in ['Iris-Setosa','Iris-Versicolor','Iris-Virginica']],
                      columns=[i for i in [['Predicted Iris-Setosa','Predicted Iris-Versicolor','Predicted Iris-Virginica']]])
    plt.figure(figsize=(7,4))
    sns.heatmap(data=df_cm,annot=True,fmt='g')

# %%
#Logistic Regression

# %%
lg=LogisticRegression()
model(lg,df)
# Out:
#                  precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00        19
# Iris-versicolor       1.00      1.00      1.00        13
#  Iris-virginica       1.00      1.00      1.00        13
#
#        accuracy                           1.00        45
#       macro avg       1.00      1.00      1.00        45
#    weighted avg       1.00      1.00      1.00        45
#
#
#
# The accuracy is 1.0

# %%
#GaussianNB

# %%
gb=GaussianNB()
model(gb,df)
# Out:
#                  precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00        19
# Iris-versicolor       1.00      0.92      0.96        13
#  Iris-virginica       0.93      1.00      0.96        13
#
#        accuracy                           0.98        45
#       macro avg       0.98      0.97      0.97        45
#    weighted avg       0.98      0.98      0.98        45
#
#
#
# The accuracy is 0.98

# %%
#Decision Tree

# %%
dt=DecisionTreeClassifier()
model(dt,df)
# Out:
#                  precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00        19
# Iris-versicolor       1.00      1.00      1.00        13
#  Iris-virginica       1.00      1.00      1.00        13
#
#        accuracy                           1.00        45
#       macro avg       1.00      1.00      1.00        45
#    weighted avg       1.00      1.00      1.00        45
#
#
#
# The accuracy is 1.0

# %%
#KNeighbors

# %%
kn=KNeighborsClassifier()
model(kn,df)
# Out:
#                  precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00        19
# Iris-versicolor       1.00      1.00      1.00        13
#  Iris-virginica       1.00      1.00      1.00        13
#
#        accuracy                           1.00        45
#       macro avg       1.00      1.00      1.00        45
#    weighted avg       1.00      1.00      1.00        45
#
#
#
# The accuracy is 1.0

# %%
#Random Forest

# %%
rf=RandomForestClassifier()
model(rf,df)
# Out:
#                  precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00        19
# Iris-versicolor       1.00      1.00      1.00        13
#  Iris-virginica       1.00      1.00      1.00        13
#
#        accuracy                           1.00        45
#       macro avg       1.00      1.00      1.00        45
#    weighted avg       1.00      1.00      1.00        45
#
#
#
# The accuracy is 1.0

# %%
#Gradient Boosting

# %%
gb=GradientBoostingClassifier()
model(gb,df)
# Out:
#                  precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00        19
# Iris-versicolor       1.00      1.00      1.00        13
#  Iris-virginica       1.00      1.00      1.00        13
#
#        accuracy                           1.00        45
#       macro avg       1.00      1.00      1.00        45
#    weighted avg       1.00      1.00      1.00        45
#
#
#
# The accuracy is 1.0

# %%
#Adaboost

# %%
ab=AdaBoostClassifier()
model(ab,df)
# Out:
#                  precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00        19
# Iris-versicolor       1.00      1.00      1.00        13
#  Iris-virginica       1.00      1.00      1.00        13
#
#        accuracy                           1.00        45
#       macro avg       1.00      1.00      1.00        45
#    weighted avg       1.00      1.00      1.00        45
#
#
#
# The accuracy is 1.0

# %%
#Support Vector Machine

# %%
svm=SVC()
model(svm,df)
# Out:
#                  precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00        19
# Iris-versicolor       1.00      1.00      1.00        13
#  Iris-virginica       1.00      1.00      1.00        13
#
#        accuracy                           1.00        45
#       macro avg       1.00      1.00      1.00        45
#    weighted avg       1.00      1.00      1.00        45
#
#
#
# The accuracy is 1.0

# %%
#All the algorithms except Gaussian NB give 100% accuracy, Gaussian NB gives 98% accuracy

# %%
#finalising

# %%
#we will use Random Forest for the final model

# %%
final_model=RandomForestClassifier()
model(final_model,df)
# Out:
#                  precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00        19
# Iris-versicolor       1.00      1.00      1.00        13
#  Iris-virginica       1.00      1.00      1.00        13
#
#        accuracy                           1.00        45
#       macro avg       1.00      1.00      1.00        45
#    weighted avg       1.00      1.00      1.00        45
#
#
#
# The accuracy is 1.0

# %%
#Dumping the model

# %%
import joblib

# %%
joblib.dump(final_model,'final_model.pkl')
# Out:
# ['final_model.pkl']

# %%
joblib.dump(list(X.columns),'col_names.pkl')
# Out:
# ['col_names.pkl']

# %%
#Loading the model

# %%
new_cols=joblib.load('col_names.pkl')

# %%
loaded_model=joblib.load('final_model.pkl')

# %%
loaded_model.predict([[5.1,3.5,2.4,0.2]])
# Out:
# array(['Iris-setosa'], dtype=object)

# %%
loaded_model.predict([[5.7,3.0,4.2,1.2]])
# Out:
# array(['Iris-versicolor'], dtype=object)

# %%
loaded_model.predict([[6.7,3.0,5.2,2.3]])
# Out:
# array(['Iris-virginica'], dtype=object)
